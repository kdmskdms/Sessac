# %% [markdown]
# ### mlb 타자 및 투수 스탯 관련 진행

# %% [markdown]
# ### 크롤링 진행

# %%
# 크롤링 및 시각화를 위한 라이브러리 블러오기
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# %%
#크롬 창 열기
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument('--disable-gpu')  

#url 주소 불러오기
chromeDriver = webdriver.Chrome(options=chrome_options)
chromeDriver.get("https://www.baseball-reference.com/leagues/majors/2023.shtml")

# 페이지 로딩 대기 (IP 밴 방지)
chromeDriver.implicitly_wait(10)

# XPath를 사용하여 원하는 요소 찾기
target_elements = chromeDriver.find_elements(By.XPATH, '//*[@id="div_teams_standard_batting"]')


# 찾은 요소가 있다면 첫 번째 요소의 텍스트 추출
if target_elements:
    print(target_elements)
    print('-'*100)
    target_element = target_elements[0]
    
    # 추출한 텍스트를 줄 단위로 나누어 리스트로 만들기
    lines = target_element.text.split('\n')
    print(lines)
    # 원하는 부분 선택 (48번째부터 53번째까지)
    selected_lines = lines[1:31]
    
# # 브라우저 종료
chromeDriver.quit()
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="24a33564e5657fbbd1f660049276192b", element="DFA893CE1A36E1A32EB7B538C74D53CF_element_43")>]
# ----------------------------------------------------------------------------------------------------
# ['Tm #Bat BatAge R/G G PA AB R H 2B 3B HR RBI SB CS BB SO BA OBP SLG OPS OPS+ TB GDP HBP SH SF IBB LOB', 'Arizona Diamondbacks 54 27.4 4.60 162 6124 5436 746 1359 274 44 166 706 166 26 540 1247 .250 .322 .408 .730 98 2219 121 58 36 50 11 1091', 'Atlanta Braves 53 27.9 5.85 162 6249 5597 947 1543 293 23 307 916 132 27 538 1289 .276 .344 .501 .845 124 2803 128 67 2 43 20 1062', 'Baltimore Orioles 50 27.3 4.98 162 6123 5495 807 1399 309 28 183 780 114 24 512 1370 .255 .321 .421 .742 107 2313 114 45 21 47 14 1041', 'Boston Red Sox 56 28.6 4.77 162 6174 5562 772 1437 339 19 182 734 112 26 486 1372 .258 .324 .424 .748 100 2360 118 71 11 35 15 1117', 'Chicago Cubs 48 28.4 5.06 162 6220 5504 819 1399 269 30 196 786 140 34 570 1391 .254 .330 .421 .751 101 2316 95 77 15 52 11 1127', 'Chicago White Sox 56 27.8 3.96 162 5980 5501 641 1308 264 13 171 617 86 22 377 1424 .238 .291 .384 .675 83 2111 122 52 16 29 19 1009', 'Cincinnati Reds 65 26.8 4.83 162 6195 5499 783 1371 268 37 198 747 190 48 556 1500 .249 .327 .420 .746 99 2307 101 92 19 29 8 1107', 'Cleveland Guardians 50 26.6 4.09 162 6096 5513 662 1379 294 29 124 622 151 36 471 1142 .250 .313 .381 .695 94 2103 108 55 13 44 40 1121', 'Colorado Rockies 57 28.1 4.45 162 6055 5496 721 1368 305 31 163 685 76 25 447 1543 .249 .310 .405 .715 83 2224 124 59 11 41 8 1038', 'Detroit Tigers 51 27.4 4.08 162 6080 5478 661 1292 245 29 165 635 85 23 508 1473 .236 .305 .382 .686 87 2090 107 49 13 31 10 1103', 'Houston Astros 41 28.8 5.10 162 6253 5567 827 1441 280 22 222 799 107 32 
    # 각 행을 공백으로 나누어 리스트로 만들기
    items = line.split()
    
    # 이름은 리스트의 처음부터 마지막에서 28번째 이전까지의 항목
    name = ' '.join(items[:-28])
    
    # 데이터는 마지막에서 28번째부터 끝까지의 항목
    data = items[-28:]
    
    # 이름과 데이터를 리스트에 추가
    processed_data.append([name] + data)

# 처리된 데이터 출력
for item in processed_data:
    print(item)
# Out:
# ['Arizona Diamondbacks', '54', '27.4', '4.60', '162', '6124', '5436', '746', '1359', '274', '44', '166', '706', '166', '26', '540', '1247', '.250', '.322', '.408', '.730', '98', '2219', '121', '58', '36', '50', '11', '1091']
# ['Atlanta Braves', '53', '27.9', '5.85', '162', '6249', '5597', '947', '1543', '293', '23', '307', '916', '132', '27', '538', '1289', '.276', '.344', '.501', '.845', '124', '2803', '128', '67', '2', '43', '20', '1062']
# ['Baltimore Orioles', '50', '27.3', '4.98', '162', '6123', '5495', '807', '1399', '309', '28', '183', '780', '114', '24', '512', '1370', '.255', '.321', '.421', '.742', '107', '2313', '114', '45', '21', '47', '14', '1041']
# ['Boston Red Sox', '56', '28.6', '4.77', '162', '6174', '5562', '772', '1437', '339', '19', '182', '734', '112', '26', '486', '1372', '.258', '.324', '.424', '.748', '100', '2360', '118', '71', '11', '35', '15', '1117']
# ['Chicago Cubs', '48', '28.4', '5.06', '162', '6220', '5504', '819', '1399', '269', '30', '196', '786', '140', '34', '570', '1391', '.254', '.330', '.421', '.751', '101', '2316', '95', '77', '15', '52', '11', '1127']
# ['Chicago White Sox', '56', '27.8', '3.96', '162', '5980', '5501', '641', '1308', '264', '13', '171', '617', '86', '22', '377', '1424', '.238', '.291', '.384', '.675', '83', '2111', '122', '52', '16', '29', '19', '1009']
# ['Cincinnati Reds', '65', '26.8', '4.83', '162', '6195', '5499', '783', '1371', '268', '37', '198', '747', '190', '48', '556', '1500', '.249', '.327', '.420', '.746', '99', '2307', '101', '92', '19', '29', '8', '1107']
# ['Cleveland Guardians', '50', '26.6', '4.09', '162', '6096', '5513', '662', '1379', '294', '29', '124', '622', '151', '36', '471', '1142', '.250', '.313', '.381', '.695', '94', '2103', '108', '55', '13', '44', '40', '1121']
# ['Colorado Rockies', '57', '28.1', '4.45', '162', '6055', '5496', '721', '1368', '305', '31', '163', '685', '76', '25', '447', '1543', '.249', '.310', '.405', '.715', '83', '2224', '124', '59', '11', '41', '8', '1038']
# ['Detroit Tigers', '51', '27.4', '4.08', '162', '6080', '5478', '661', '1292', '245', '29', '165', '635', '85', '23', '508', '1473', '.236', '.305', '.382', '.686', '87', '2090', '107', '49', '13', '31', '10', '1103']
# ['Houston Astros', '41', '28.8', '5.10', '162', '6253', '5567', '827', '1441', '280', '22', '222', '799', '107', '32', '550', '1241', '.259', '.331', '.437', '.768', '111', '2431', '124', '72', '14', '40', '17', '1134']
# ['Kansas City Royals', '58', '26.3', '4.17', '162', '5985', '5428', '676', '1325', '258', '43', '163', '651', '163', '47', '411', '1396', '.244', '.303', '.398', '.700', '91', '2158', '96', '71', '14', '58', '12', '1009']
# ['Tampa Bay Rays', '58', '26.8', '5.31', '162', '6164', '5511', '860', '1432', '282', '24', '230', '827', '160', '41', '514', '1420', '.260', '.331', '.445', '.776', '114', '2452', '109', '95', '6', '38', '7', '1047']
# ['Texas Rangers', '48', '28.3', '5.44', '162', '6306', '5595', '881', '1470', '326', '18', '233', '845', '79', '19', '599', '1416', '.263', '.337', '.452', '.790', '113', '2531', '103', '53', '10', '47', '17', '1164']
# ['Toronto Blue Jays', '46', '28.8', '4.60', '162', '6220', '5562', '746', '1423', '292', '19', '188', '705', '99', '34', '550', '1303', '.256', '.329', '.417', '.745', '106', '2317', '129', '69', '4', '32', '14', '1170']
# ['Washington Nationals', '48', '26.8', '4.32', '162', '6085', '5522', '700', '1401', '279', '26', '151', '665', '127', '29', '423', '1149', '.254', '.314', '.396', '.709', '95', '2185', '112', '78', '20', '38', '6', '1082']

# %%
#데이터 프레임으로 변경
df = pd.DataFrame(processed_data)

# %%
# 컬럼명 이름 설정
columns = ['Team', '#Bat','BatAge','R/G','G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG','OPS','OPS+','TB','GDP','HBP','SH','SF','IBB','LOB']

# %%
# 현재의 컬럼 이름 출력
print("현재 컬럼 이름:")
print(df.columns)

# 컬럼 이름 변경
df.columns = columns

# 변경된 컬럼 이름 출력
print("\n변경된 컬럼 이름:")
print(df.columns)
# Out:
# 현재 컬럼 이름:
# RangeIndex(start=0, stop=29, step=1)
#
# 변경된 컬럼 이름:
# Index(['Team', '#Bat', 'BatAge', 'R/G', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B',
#        'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+',
#        'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB', 'LOB'],
#       dtype='object')

# %%
# 데이터 프레임 항목 변경 확인
df.head()
# Out:
#                    Team #Bat BatAge   R/G    G    PA    AB    R     H   2B  \
# 0  Arizona Diamondbacks   54   27.4  4.60  162  6124  5436  746  1359  274
# 1        Atlanta Braves   53   27.9  5.85  162  6249  5597  947  1543  293
# 2     Baltimore Orioles   50   27.3  4.98  162  6123  5495  807  1399  309
# 3        Boston Red Sox   56   28.6  4.77  162  6174  5562  772  1437  339
# 4          Chicago Cubs   48   28.4  5.06  162  6220  5504  819  1399  269
#
#    ...   SLG   OPS OPS+    TB  GDP HBP  SH  SF IBB   LOB
# 0  ...  .408  .730   98  2219  121  58  36  50  11  1091
# 1  ...  .501  .845  124  2803  128  67   2  43  20  1062
# 2  ...  .421  .742  107  2313  114  45  21  47  14  1041
# 3  ...  .424  .748  100  2360  118  71  11  35  15  1117
# 4  ...  .421  .751  101  2316   95  77  15  52  11  1127
#
# [5 rows x 29 columns]

# %%
df.to_csv('Team Standard Batting.csv')

# %%
import pandas as pd

# 'Team' 열을 제외한 모든 열을 선택
columns_to_convert = df.columns.difference(['Team'])

# 선택한 열을 모두 float로 변환
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  30 non-null     int64
#  1   Team        30 non-null     object
#  2   #Bat        30 non-null     int64
#  3   BatAge      30 non-null     float64
#  4   R/G         30 non-null     float64
#  5   G           30 non-null     int64
#  6   PA          30 non-null     int64
#  7   AB          30 non-null     int64
#  8   R           30 non-null     int64
#  9   H           30 non-null     int64
#  10  2B          30 non-null     int64
#  11  3B          30 non-null     int64
#  12  HR          30 non-null     int64
#  13  RBI         30 non-null     int64
#  14  SB          30 non-null     int64
#  15  CS          30 non-null     int64
#  16  BB          30 non-null     int64
#  17  SO          30 non-null     int64
#  18  BA          30 non-null     float64
#  19  OBP         30 non-null     float64
#  20  SLG         30 non-null     float64
#  21  OPS         30 non-null     float64
#  22  OPS+        30 non-null     int64
#  23  TB          30 non-null     int64
#  24  GDP         30 non-null     int64
#  25  HBP         30 non-null     int64
#  26  SH          30 non-null     int64
#  27  SF          30 non-null     int64
#  28  IBB         30 non-null     int64
#  29  LOB         30 non-null     int64
#  30  Cluster     30 non-null     int64
# dtypes: float64(6), int64(24), object(1)
# memory usage: 7.4+ KB

# %%
import pandas as pd
df = pd.read_csv('Team Standard Batting.csv')

# %%
from scipy.stats import f_oneway

# 30개 구단 선택
teams = df['Team'].unique()[:30]

# 구단별 'OPS+' 값을 저장할 리스트
ops_list = []

# 각 구단의 'OPS+' 값을 구해서 리스트에 추가
for team in teams:
    ops = df[df['Team'] == team]['OPS+']
    ops_list.append(ops)

# ANOVA 수행
f_stat, p_value = f_oneway(*ops_list)

# p-value가 0.05보다 작으면 유의미한 차이가 있다고 판단
if p_value < 0.05:
    print("구단 간에는 통계적으로 유의미한 차이가 있습니다.")
    print(f"F-statistic: {f_stat}")
else:
    print("차이가 없거나 유의미하지 않은 차이가 있습니다.")
# Out:
# 차이가 없거나 유의미하지 않은 차이가 있습니다.
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\scipy\stats\_stats_py.py:4141: DegenerateDataWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   warnings.warn(stats.DegenerateDataWarning(msg))

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# 'HR'을 기준으로 클러스터링
X = df[['HR']].values

# 데이터 표준화 (Standardization)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# K-means 클러스터링 수행 (예: 3개의 클러스터)
kmeans = KMeans(n_clusters=3, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_std)

# 클러스터별 평균 HR 값 계산
cluster_means = df.groupby('Cluster')['HR'].mean()

# 시각화
plt.scatter(X_std[:, 0], df['HR'], c=df['Cluster'], cmap='viridis')
plt.scatter(cluster_means.index, cluster_means.values, c='red', marker='X', s=200, label='Cluster Mean')
plt.xlabel('Standardized HR')
plt.ylabel('HR')
plt.legend()
plt.show()
# Out:
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# 'HR'을 기준으로 클러스터링
X = df[['HR']].values

# 데이터 표준화 (Standardization)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# Gaussian Mixture Model 클러스터링 수행 (예: 3개의 클러스터, 타원형)
gmm = GaussianMixture(n_components=3, covariance_type='full', random_state=42)
df['Cluster'] = gmm.fit_predict(X_std)

# 시각화
plt.scatter(X_std[:, 0], df['HR'], c=df['Cluster'], cmap='viridis')
plt.xlabel('Standardized HR')
plt.ylabel('HR')
plt.show()
# Out:
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import numpy as np

# 'HR'을 기준으로 클러스터링
X = df[['HR']].values

# 데이터 표준화 (Standardization)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# DBSCAN 클러스터링 수행
dbscan = DBSCAN(eps=0.5, min_samples=5)
df['Cluster_DBSCAN'] = dbscan.fit_predict(X_std)

# 시각화
plt.scatter(X_std[:, 0], df['HR'], c=df['Cluster_DBSCAN'], cmap='viridis')
plt.xlabel('Standardized HR')
plt.ylabel('HR')
plt.title('DBSCAN Clustering')
plt.show()

# %%
import mkl
mkl.set_num_threads(1)

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import os
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
os.environ['OMP_NUM_THREADS'] = '1'

# 'H'을 기준으로 클러스터링
X = df[['H']].values

# 데이터 표준화 (Standardization)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# K-means 클러스터링 수행 (예: 3개의 클러스터)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(X_std)


# 클러스터별 평균 HR 값 계산
cluster_means = df.groupby('Cluster')['H'].mean()

# 시각화
plt.scatter(X_std[:, 0], df['H'], c=df['Cluster'], cmap='viridis')
plt.scatter(cluster_means.index, cluster_means.values, c='red', marker='X', s=200, label='Cluster Mean')
plt.xlabel('Standardized H')
plt.ylabel('H')
plt.legend()
plt.show()
# Out:
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import mkl
mkl.set_num_threads(1)

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import os
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
os.environ['OMP_NUM_THREADS'] = '1'

# 'H'을 기준으로 클러스터링
X = df[['OPS+']].values

# 데이터 표준화 (Standardization)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# K-means 클러스터링 수행 (예: 3개의 클러스터)
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(X_std)

# 클러스터별 평균 HR 값 계산
cluster_means = df.groupby('Cluster')['OPS+'].mean()

# 시각화
plt.scatter(X_std[:, 0], df['OPS+'], c=df['Cluster'], cmap='viridis')
plt.scatter(cluster_means.index, cluster_means.values, c='red', marker='X', s=200, label='Cluster Mean')
plt.xlabel('Standardized OPS+')
plt.ylabel('OPS+')
plt.legend()
plt.show()
# Out:
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 판다스 DataFrame에서 '팀'과 '홈런' 열을 사용하여 시각화
ax = sns.barplot(x='HR', y='Team', data=df)

# 평균값 계산
mean_value = df['HR'].mean()

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (hr, team) in enumerate(zip(df['HR'], df['Team'])):
    color = 'red' if hr > mean_value else 'blue'
    ax.text(hr, idx, f'{hr}', color=color, ha="left", va="center")

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean HR')

# 막대 색상 설정
colors = ['red' if hr > mean_value else 'blue' for hr in df['HR']]
for bar, color in zip(ax.patches, colors):
    bar.set_facecolor(color)

# 그래프 제목 추가
plt.title('팀별 홈런 수')

# y축 라벨 회전
plt.yticks(rotation=0)

# 범례 추가
plt.legend()

# 그래프 출력
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# 한글 폰트 설정
mpl.rcParams['font.family'] = 'Malgun Gothic'

# 판다스 DataFrame에서 '팀'과 '홈런' 열을 사용하여 시각화
ax = sns.barplot(x='HR', y='Team', data=df.sort_values('HR', ascending=False))

# 평균값 계산
mean_value = df['HR'].mean()

# 평균값을 넘은 데이터를 빨간색으로, 넘지 않은 데이터를 파란색으로 색칠하고 표시
for idx, (team, hr) in enumerate(zip(df.sort_values('HR', ascending=False)['Team'], df.sort_values('HR', ascending=False)['HR'])):
    color = 'red' if hr > mean_value else 'blue'
    ax.text(hr, idx, f'{hr}', color=color, ha="left", va="center")

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean HR')

# 막대 색상 설정
bar_colors = ['red' if hr > mean_value else 'blue' for hr in df.sort_values('HR', ascending=False)['HR']]
for bar, color in zip(ax.patches, bar_colors):
    bar.set_facecolor(color)

# 그래프 제목 추가
plt.title('팀별 홈런 수')

# y축 라벨 회전
plt.yticks(rotation=0)

# 범례 추가
plt.legend()

# 그래프 출력
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 평균값 계산
mean_value = df['H'].mean()

# 판다스 DataFrame에서 '팀'과 '홈런' 열을 사용하여 시각화
ax = sns.barplot(x='H', y='Team', data=df, hue=colors, dodge=False)

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (h, team) in enumerate(zip(df['H'], df['Team'])):
    color = 'red' if h > mean_value else 'blue'
    ax.text(h, idx, f'{h}', color=color, ha="left", va="center") 

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean H')

# 그래프 제목 추가
plt.title('팀별 안타 수')
# 범례 및 제목 제거
ax.legend().set_visible(False)

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 평균값 계산
mean_value = df['H'].mean()

# 판다스 DataFrame에서 '팀'과 '안타' 열을 사용하여 시각화
ax = sns.barplot(x='H', y='Team', data=df.sort_values('H', ascending=False), dodge=False)

# 평균값을 넘은 데이터를 빨간색으로, 넘지 않은 데이터를 파란색으로 색칠하고 표시
for idx, (team, h) in enumerate(zip(df.sort_values('H', ascending=False)['Team'], df.sort_values('H', ascending=False)['H'])):
    color = 'red' if h > mean_value else 'blue'
    ax.text(h, idx, f'{h}', color=color, ha="left", va="center") 

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean H')

# 막대 색상 설정
bar_colors = ['red' if h > mean_value else 'blue' for h in df.sort_values('H', ascending=False)['H']]
for bar, color in zip(ax.patches, bar_colors):
    bar.set_facecolor(color)

# 그래프 제목 추가
plt.title('팀별 안타 수')

# 범례 및 제목 제거
ax.legend().set_visible(False)

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 평균값 계산
mean_value = df['OPS'].mean()

# 판다스 DataFrame에서 '팀'과 'OPS+' 열을 사용하여 시각화
ax = sns.barplot(x='OPS', y='Team', data=df, hue=colors, dodge=False)

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (ops, team) in enumerate(zip(df['OPS'], df['Team'])):
    color = 'red' if ops > mean_value else 'blue'
    ax.text(ops, idx, f'{ops}', color=color, ha="left", va="center") 

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean OPS')

# 그래프 제목 추가
plt.title('팀별 OPS')
# 범례 및 제목 제거
ax.legend().set_visible(False)

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 평균값 계산
mean_value = df['OPS'].mean()

# 판다스 DataFrame에서 '팀'과 'OPS' 열을 사용하여 시각화
ax = sns.barplot(x='OPS', y='Team', data=df.sort_values('OPS', ascending=False), dodge=False)

# 평균값을 넘은 데이터를 빨간색으로, 넘지 않은 데이터를 파란색으로 색칠하고 표시
for idx, (team, ops) in enumerate(zip(df.sort_values('OPS', ascending=False)['Team'], df.sort_values('OPS', ascending=False)['OPS'])):
    color = 'red' if ops > mean_value else 'blue'
    ax.text(ops, idx, f'{ops}', color=color, ha="left", va="center") 

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean OPS')

# 막대 색상 설정
bar_colors = ['red' if ops > mean_value else 'blue' for ops in df.sort_values('OPS', ascending=False)['OPS']]
for bar, color in zip(ax.patches, bar_colors):
    bar.set_facecolor(color)

# 그래프 제목 추가
plt.title('팀별 OPS')

# 범례 및 제목 제거
ax.legend().set_visible(False)

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()

# %%
bat = pd.read_csv('Team Standard Batting.csv')
bat=bat.sort_values(by='HR', ascending=False)

# %%
hr_column = bat[['Team','HR']].copy()
hr_column
# Out:
#                      Team   HR
# 1          Atlanta Braves  307
# 13    Los Angeles Dodgers  249
# 16        Minnesota Twins  233
# 27          Texas Rangers  233
# 12     Los Angeles Angels  231
# 26         Tampa Bay Rays  230
# 10         Houston Astros  222
# 20  Philadelphia Phillies  220
# 18       New York Yankees  219
# 17          New York Mets  215
# 23       Seattle Mariners  210
# 25    St. Louis Cardinals  209
# 22       San Diego Padres  205
# 6         Cincinnati Reds  198
# 4            Chicago Cubs  196
# 28      Toronto Blue Jays  188
# 2       Baltimore Orioles  183
# 3          Boston Red Sox  182
# 24   San Francisco Giants  174
# 5       Chicago White Sox  171
# 19      Oakland Athletics  171
# 14          Miami Marlins  166
# 0    Arizona Diamondbacks  166
# 15      Milwaukee Brewers  165
# 9          Detroit Tigers  165
# 11     Kansas City Royals  163
# 8        Colorado Rockies  163
# 21     Pittsburgh Pirates  159
# 29   Washington Nationals  151
# 7     Cleveland Guardians  124

# %%
bat = pd.read_csv('Team Standard Batting.csv')
bat=bat.sort_values(by='H', ascending=False)

# %%
h_column = bat[['Team','H']].copy()
h_column
# Out:
#                      Team     H
# 1          Atlanta Braves  1543
# 13    Los Angeles Dodgers  1422
# 27          Texas Rangers  1470
# 26         Tampa Bay Rays  1432
# 10         Houston Astros  1441
# 20  Philadelphia Phillies  1417
# 16        Minnesota Twins  1336
# 4            Chicago Cubs  1399
# 3          Boston Red Sox  1437
# 6         Cincinnati Reds  1371
# 28      Toronto Blue Jays  1423
# 12     Los Angeles Angels  1346
# 22       San Diego Padres  1316
# 25    St. Louis Cardinals  1376
# 2       Baltimore Orioles  1399
# 23       Seattle Mariners  1332
# 0    Arizona Diamondbacks  1359
# 17          New York Mets  1276
# 14          Miami Marlins  1423
# 8        Colorado Rockies  1368
# 29   Washington Nationals  1401
# 21     Pittsburgh Pirates  1293
# 15      Milwaukee Brewers  1290
# 18       New York Yankees  1207
# 11     Kansas City Royals  1325
# 24   San Francisco Giants  1271
# 7     Cleveland Guardians  1379
# 9          Detroit Tigers  1292
# 5       Chicago White Sox  1308
# 19      Oakland Athletics  1187

# %%
bat = pd.read_csv('Team Standard Batting.csv')
bat=bat.sort_values(by='OPS', ascending=False)

# %%
ops_column = bat[['Team','OPS']].copy()
ops_column
# Out:
#                      Team    OPS
# 1          Atlanta Braves  0.845
# 13    Los Angeles Dodgers  0.795
# 27          Texas Rangers  0.790
# 26         Tampa Bay Rays  0.776
# 10         Houston Astros  0.768
# 20  Philadelphia Phillies  0.765
# 16        Minnesota Twins  0.753
# 4            Chicago Cubs  0.751
# 3          Boston Red Sox  0.748
# 6         Cincinnati Reds  0.746
# 28      Toronto Blue Jays  0.745
# 12     Los Angeles Angels  0.743
# 22       San Diego Padres  0.742
# 25    St. Louis Cardinals  0.742
# 2       Baltimore Orioles  0.742
# 23       Seattle Mariners  0.734
# 0    Arizona Diamondbacks  0.730
# 17          New York Mets  0.723
# 14          Miami Marlins  0.721
# 8        Colorado Rockies  0.715
# 29   Washington Nationals  0.709
# 21     Pittsburgh Pirates  0.707
# 15      Milwaukee Brewers  0.704
# 18       New York Yankees  0.701
# 11     Kansas City Royals  0.700
# 24   San Francisco Giants  0.695
# 7     Cleveland Guardians  0.695
# 9          Detroit Tigers  0.686
# 5       Chicago White Sox  0.675
# 19      Oakland Athletics  0.669

# %% [markdown]
# ### 투수파트

# %%
#크롬 창 열기
chrome_options = Options()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chrome_options.add_argument('--disable-gpu')  

#url 주소 불러오기
chromeDriver = webdriver.Chrome(options=chrome_options)
chromeDriver.get("https://www.baseball-reference.com/leagues/majors/2023.shtml")

# 페이지 로딩 대기 (IP 밴 방지)
chromeDriver.implicitly_wait(10)

# XPath를 사용하여 원하는 요소 찾기
target_elements = chromeDriver.find_elements(By.XPATH, '//*[@id="teams_standard_pitching"]')


# 찾은 요소가 있다면 첫 번째 요소의 텍스트 추출
if target_elements:
    print(target_elements)
    print('-'*100)
    target_element = target_elements[0]
    
    # 추출한 텍스트를 줄 단위로 나누어 리스트로 만들기
    lines = target_element.text.split('\n')
    print(lines)
    # 원하는 부분 선택 (48번째부터 53번째까지)
    selected_lines2 = lines[1:31]
    
# # 브라우저 종료
chromeDriver.quit()
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session
652 200 454 20 1388 73 4 49 6018 108 4.23 1.202 8.0 1.2 2.8 8.6 3.06 1000', 'Miami Marlins 32 27.6 4.46 84 78 .519 4.21 162 162 159 3 9 1 43 1435.1 1340 723 672 191 514 20 1490 71 9 38 6091 107 4.13 1.292 8.4 1.2 3.2 9.3 2.90 1081', 'Milwaukee Brewers 34 29.3 3.99 92 70 .568 3.71 162 162 161 1 16 1 46 1443.0 1218 647 595 198 493 7 1425 60 8 54 5990 116 4.21 1.186 7.6 1.2 3.1 8.9 2.89 1036', 'Minnesota Twins 29 29.0 4.07 87 75 .537 3.87 162 162 160 2 12 2 38 1451.1 1294 659 624 194 443 16 1560 63 1 51 6028 111 3.89 1.197 8.0 1.2 2.7 9.7 3.52 1046', 'New York Mets 37 31.9 4.50 75 87 .463 4.30 162 162 161 1 7 0 34 1416.1 1331 729 676 190 595 13 1397 85 8 59 6115 99 4.47 1.360 8.5 1.2 3.8 8.9 2.35 1147', 'New York Yankees 32 29.1 4.31 82 80 .506 3.97 162 162 159 3 8 3 44 1439.2 1272 698 635 195 508 6 1439 85 15 60 6078 110 4.25 1.236 8.0 1.2 3.2 9.0 2.83 1080', 'Oakland Athletics 41 28.0 5.70 50 112 .309 5.48 162 162 162 0 5 0 29 1419.2 1464 924 865 213 694 33 1300 100 4 76 6384 75 5.05 1.520 9.3 1.4 4.4 8.2 1.87 1219', 'Philadelphia Phillies 26 29.8 4.41 90 72 .556 4.03 162 162 161 1 4 1 45 1442.1 1318 715 646 185 470 6 1454 54 7 35 6074 107 4.00 1.240 8.2 1.2 2.9 9.1 3.09 1056', 'Pittsburgh Pirates 30 27.6 4.88 76 86 .469 4.60 162 162 160 2 10 2 47 1430.0 1380 790 731 179 596 25 1363 81 7 57 6238 97 4.40 1.382 8.7 1.1 3.8 8.6 2.29 1171', 'San Diego Padres 30 30.7 4.00 82 80 .506 3.73 162 162 162 0 16 0 36 1441.0 1270 648 598 174 557 14 1445 76 7 48 6082 110 4.14 1.268 7.9 1.1 3.5 9.0 2.59 1131', 'Seattle Mariners 35 27.4 4.07 88 74 .543 3.74 162 162 160 2 18 1 44 1449.1 1300 659 602 184 421 22 1459 57 4 41 6006 109 3.88 1.187 8.1 1.1 2.6 9.1 3.47 1026', 'San Francisco Gian ...

# %%
processed_data2 = []  # 처리된 데이터를 저장할 리스트

# 각 행에 대해 반복
for line in selected_lines2:
    # 각 행을 공백으로 나누어 리스트로 만들기
    items = line.split()
    
    # 이름은 리스트의 처음부터 마지막에서 36번째 이전까지의 항목
    name = ' '.join(items[:-35])
    
    # 데이터는 마지막에서 36번째부터 끝까지의 항목
    data = items[-35:]
    
    # 이름과 데이터를 리스트에 추가
    processed_data2.append([name] + data)

# 처리된 데이터 출력
for item in processed_data2:
    print(item)
# Out:
# ['Arizona Diamondbacks', '34', '28.5', '4.70', '84', '78', '.519', '4.47', '162', '162', '161', '1', '9', '1', '44', '1435.1', '1375', '761', '713', '197', '525', '13', '1351', '48', '8', '40', '6100', '98', '4.35', '1.324', '8.6', '1.2', '3.3', '8.5', '2.57', '1050']
# ['San Diego Padres', '30', '30.7', '4.00', '82', '80', '.506', '3.73', '162', '162', '162', '0', '16', '0', '36', '1441.0', '1270', '648', '598', '174', '557', '14', '1445', '76', '7', '48', '6082', '110', '4.14', '1.268', '7.9', '1.1', '3.5', '9.0', '2.59', '1131']
# ['Seattle Mariners', '35', '27.4', '4.07', '88', '74', '.543', '3.74', '162', '162', '160', '2', '18', '1', '44', '1449.1', '1300', '659', '602', '184', '421', '22', '1459', '57', '4', '41', '6006', '109', '3.88', '1.187', '8.1', '1.1', '2.6', '9.1', '3.47', '1026']
# ['San Francisco Giants', '24', '30.0', '4.44', '79', '83', '.488', '4.02', '162', '162', '158', '4', '11', '2', '50', '1434.2', '1395', '719', '641', '173', '403', '22', '1359', '71', '12', '60', '6039', '105', '3.92', '1.253', '8.8', '1.1', '2.5', '8.5', '3.37', '1038']
# ['St. Louis Cardinals', '28', '29.7', '5.12', '71', '91', '.438', '4.79', '162', '162', '162', '0', '10', '0', '36', '1428.1', '1549', '829', '760', '179', '530', '6', '1215', '63', '7', '62', '6273', '90', '4.43', '1.456', '9.8', '1.1', '3.3', '7.7', '2.29', '1172']
# ['Tampa Bay Rays', '40', '28.5', '4.10', '99', '63', '.611', '3.86', '162', '162', '162', '0', '14', '0', '45', '1442.0', '1258', '665', '618', '177', '439', '10', '1507', '63', '1', '65', '5994', '108', '3.80', '1.177', '7.9', '1.1', '2.7', '9.4', '3.43', '1019']
# ['Texas Rangers', '31', '30.4', '4.42', '90', '72', '.556', '4.28', '162', '162', '159', '3', '13', '1', '30', '1436.1', '1330', '716', '683', '198', '491', '19', '1351', '59', '4', '46', '6025', '105', '4.31', '1.268', '8.3', '1.2', '3.1', '8.5', '2.75', '1016']
# ['Toronto Blue Jays', '26', '30.6', '4.14', '89', '73', '.549', '3.78', '162', '162', '161', '1', '15', '1', '51', '1451.2', '1326', '671', '610', '198', '488', '29', '1528', '62', '12', '42', '6100', '113', '4.06', '1.250', '8.2', '1.2', '3.0', '9.5', '3.13', '1100']
# ['Washington Nationals', '28', '28.0', '5.22', '71', '91', '.438', '5.02', '162', '162', '162', '0', '3', '0', '42', '1428.1', '1512', '845', '797', '245', '592', '25', '1225', '66', '8', '54', '6285', '86', '5.15', '1.473', '9.5', '1.5', '3.7', '7.7', '2.07', '1167']

# %%
# 컬럼명 이름 설정
columns = ['Team', '#P','PAge','RA/G','W', 'L', 'W-L%', 'ERA', 'G', 'GS', 'GF', 'CG', 'tSho', 'cSho', 'SV', 'IP', 'H', 'R', 'ER', 'HR','BB','IBB','SO','HBP','BK','WP','BF','ERA+','FIP','WHIP','H9','HR9','BB9','SO9','SO/W','LOB']

# %%
#데이터 프레임으로 변경
df2 = pd.DataFrame(processed_data2)

# %%
# 현재의 컬럼 이름 출력
print("현재 컬럼 이름:")
print(df2.columns)

# 컬럼 이름 변경
df2.columns = columns

# 변경된 컬럼 이름 출력
print("\n변경된 컬럼 이름:")
print(df2.columns)
# Out:
# 현재 컬럼 이름:
# RangeIndex(start=0, stop=36, step=1)
#
# 변경된 컬럼 이름:
# Index(['Team', '#P', 'PAge', 'RA/G', 'W', 'L', 'W-L%', 'ERA', 'G', 'GS', 'GF',
#        'CG', 'tSho', 'cSho', 'SV', 'IP', 'H', 'R', 'ER', 'HR', 'BB', 'IBB',
#        'SO', 'HBP', 'BK', 'WP', 'BF', 'ERA+', 'FIP', 'WHIP', 'H9', 'HR9',
#        'BB9', 'SO9', 'SO/W', 'LOB'],
#       dtype='object')

# %%
import pandas as pd

# 'Team' 열을 제외한 모든 열을 선택
columns_to_convert = df2.columns.difference(['Team'])

# 선택한 열을 모두 float로 변환
df2[columns_to_convert] = df2[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
df2.head()
# Out:
#                    Team  #P  PAge  RA/G    W   L   W-L%   ERA    G   GS  ...  \
# 0  Arizona Diamondbacks  34  28.5  4.70   84  78  0.519  4.47  162  162  ...
# 1        Atlanta Braves  32  29.9  4.42  104  58  0.642  4.14  162  162  ...
# 2     Baltimore Orioles  31  28.4  4.19  101  61  0.623  3.89  162  162  ...
# 3        Boston Red Sox  33  30.0  4.79   78  84  0.481  4.52  162  162  ...
# 4          Chicago Cubs  27  29.6  4.46   83  79  0.512  4.08  162  162  ...
#
#      BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W   LOB
# 0  6100    98  4.35  1.324  8.6  1.2  3.3  8.5  2.57  1050
# 1  6135   108  4.10  1.302  8.4  1.2  3.3  9.5  2.84  1112
# 2  6098   106  3.98  1.243  8.3  1.1  2.9  8.9  3.03  1080
# 3  6168   101  4.37  1.338  8.9  1.3  3.1  9.0  2.86  1117
# 4  6085   110  4.16  1.283  8.3  1.1  3.2  8.6  2.68  1073
#
# [5 rows x 36 columns]

# %%
df2.to_csv('Team Standard Pitching.csv')

# %%
import pandas as pd
df2 = pd.read_csv('Team Standard Pitching.csv')

# %%
from scipy.stats import f_oneway

# 30개 구단 선택
teams = df2['Team'].unique()[:30]

# 구단별 'OPS+' 값을 저장할 리스트
ops_list = []

# 각 구단의 'OPS+' 값을 구해서 리스트에 추가
for team in teams:
    ops = df2[df2['Team'] == team]['SO']
    ops_list.append(ops)

# ANOVA 수행
f_stat, p_value = f_oneway(*ops_list)

# p-value가 0.05보다 작으면 유의미한 차이가 있다고 판단
if p_value < 0.05:
    print("구단 간에는 통계적으로 유의미한 차이가 있습니다.")
    print(f"F-statistic: {f_stat}")
else:
    print("차이가 없거나 유의미하지 않은 차이가 있습니다.")
# Out:
# 차이가 없거나 유의미하지 않은 차이가 있습니다.
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\scipy\stats\_stats_py.py:4141: DegenerateDataWarning: all input arrays have length 1.  f_oneway requires that at least one input has length greater than 1.
#   warnings.warn(stats.DegenerateDataWarning(msg))

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# 'ERA'를 기준으로 클러스터링
X = df2[['ERA']].values

# 데이터 표준화 (Standardization)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# K-means 클러스터링 수행 (예: 3개의 클러스터)
kmeans = KMeans(n_clusters=3, random_state=42)
df2['Cluster'] = kmeans.fit_predict(X_std)

# 클러스터별 평균 ERA 값 계산
cluster_means = df2.groupby('Cluster')['ERA'].mean()

# 시각화
plt.scatter(X_std[:, 0], df2['ERA'], c=df2['Cluster'], cmap='viridis')
plt.scatter(cluster_means.index, cluster_means.values, c='red', marker='X', s=200, label='Cluster Mean')
plt.xlabel('Standardized ERA')
plt.ylabel('ERA')
plt.legend()
plt.show()
# Out:
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# 'SO'를 기준으로 클러스터링
X = df2[['SO']].values

# 데이터 표준화 (Standardization)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# K-means 클러스터링 수행 (예: 3개의 클러스터)
kmeans = KMeans(n_clusters=3, random_state=42)
df2['Cluster'] = kmeans.fit_predict(X_std)

# 클러스터별 평균 ERA 값 계산
cluster_means = df2.groupby('Cluster')['SO'].mean()

# 시각화
plt.scatter(X_std[:, 0], df2['SO'], c=df2['Cluster'], cmap='viridis')
plt.scatter(cluster_means.index, cluster_means.values, c='red', marker='X', s=200, label='Cluster Mean')
plt.xlabel('Standardized SO')
plt.ylabel('SO')
plt.legend()
plt.show()
# Out:
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
# 'W'를 기준으로 클러스터링
X = df2[['W']].values

# 데이터 표준화 (Standardization)
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# K-means 클러스터링 수행 (예: 3개의 클러스터)
kmeans = KMeans(n_clusters=3, random_state=42)
df2['Cluster'] = kmeans.fit_predict(X_std)

# 클러스터별 평균 ERA 값 계산
cluster_means = df2.groupby('Cluster')['W'].mean()

# 시각화
plt.scatter(X_std[:, 0], df2['W'], c=df2['Cluster'], cmap='viridis')
plt.scatter(cluster_means.index, cluster_means.values, c='red', marker='X', s=200, label='Cluster Mean')
plt.xlabel('Standardized W')
plt.ylabel('W')
plt.legend()
plt.show()
# Out:
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\USER\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 판다스 DataFrame에서 '팀'과 '삼진' 열을 사용하여 시각화
ax = sns.barplot(x='SO', y='Team', data=df2)

# 평균값 계산
mean_value = df2['SO'].mean()

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (so, team) in enumerate(zip(df2['SO'], df2['Team'])):
    color = 'red' if so > mean_value else 'blue'
    ax.text(so, idx, f'{so}', color=color, ha="left", va="center")

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean SO')

# 막대 색상 설정
colors = ['red' if so > mean_value else 'blue' for so in df2['SO']]
for bar, color in zip(ax.patches, colors):
    bar.set_facecolor(color)

# 그래프 제목 추가
plt.title('팀별 삼진 수')

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# SO 열을 기준으로 데이터프레임을 정렬
df2_sorted = df2.sort_values(by='SO', ascending=False)

# 판다스 DataFrame에서 '팀'과 '삼진' 열을 사용하여 시각화
ax = sns.barplot(x='SO', y='Team', data=df2_sorted, palette=['red' if so > df2_sorted['SO'].mean() else 'blue' for so in df2_sorted['SO']])

# 평균값 계산
mean_value = df2_sorted['SO'].mean()

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (so, team) in enumerate(zip(df2_sorted['SO'], df2_sorted['Team'])):
    color = 'red' if so > mean_value else 'blue'
    ax.text(so, idx, f'{so}', color=color, ha="left", va="center")

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean SO')

# 그래프 제목 추가
plt.title('팀별 삼진 수')

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10940\1160704691.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='SO', y='Team', data=df2_sorted, palette=['red' if so > df2_sorted['SO'].mean() else 'blue' for so in df2_sorted['SO']])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# '세이브' 열을 기준으로 데이터프레임을 내림차순으로 정렬
df2_sorted = df2.sort_values(by='SV', ascending=False)

# 판다스 DataFrame에서 '팀'과 '세이브' 열을 사용하여 시각화
ax = sns.barplot(x='SV', y='Team', data=df2_sorted, palette=['red' if sv > df2_sorted['SV'].mean() else 'blue' for sv in df2_sorted['SV']])

# 평균값 계산
mean_value = df2_sorted['SV'].mean()

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (sv, team) in enumerate(zip(df2_sorted['SV'], df2_sorted['Team'])):
    color = 'red' if sv > mean_value else 'blue'
    ax.text(sv, idx, f'{sv}', color=color, ha="left", va="center")

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean SV')

# 그래프 제목 추가
plt.title('팀별 세이브 수')

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10940\950815389.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='SV', y='Team', data=df2_sorted, palette=['red' if sv > df2_sorted['SV'].mean() else 'blue' for sv in df2_sorted['SV']])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 판다스 DataFrame에서 '팀'과 '승' 열을 사용하여 시각화
ax = sns.barplot(x='W', y='Team', data=df2)

# 평균값 계산
mean_value = df2['W'].mean()

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (w, team) in enumerate(zip(df2['W'], df2['Team'])):
    color = 'red' if w > mean_value else 'blue'
    ax.text(w, idx, f'{w}', color=color, ha="left", va="center")

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean W')

# 그래프 제목 추가
plt.title('팀별 승 수')

# y축 라벨 회전
plt.yticks(rotation=0)


# 그래프 출력
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# '승수(W)' 열을 기준으로 데이터프레임을 정렬
df2_sorted = df2.sort_values(by='W', ascending=False)

# 판다스 DataFrame에서 '팀'과 '승수(W)' 열을 사용하여 시각화
ax = sns.barplot(x='W', y='Team', data=df2_sorted, palette=['red' if w > df2_sorted['W'].mean() else 'blue' for w in df2_sorted['W']])

# 평균값 계산
mean_value = df2_sorted['W'].mean()

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (win, team) in enumerate(zip(df2_sorted['W'], df2_sorted['Team'])):
    color = 'red' if win > mean_value else 'blue'
    ax.text(win, idx, f'{win}', color=color, ha="left", va="center")

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean W')

# 그래프 제목 추가
plt.title('팀별 승수')

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10940\4276403774.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='W', y='Team', data=df2_sorted, palette=['red' if w > df2_sorted['W'].mean() else 'blue' for w in df2_sorted['W']])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 판다스 DataFrame에서 '팀'과 'ERA' 열을 사용하여 시각화
ax = sns.barplot(x='ERA', y='Team', data=df2, orient='h')

# 평균값 계산
mean_value = df2['ERA'].mean()

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (era, team) in enumerate(zip(df2['ERA'], df2['Team'])):
    color = 'blue' if era > mean_value else 'red'
    ax.text(era, idx, f'{era:.2f}', color=color, ha="left", va="center")

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean ERA')

# 그래프 제목 추가
plt.title('팀별 평균자책점')

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 'ERA' 열을 기준으로 데이터프레임을 정렬
df2_sorted = df2.sort_values(by='ERA', ascending=True)

# 판다스 DataFrame에서 '팀'과 'ERA' 열을 사용하여 시각화
ax = sns.barplot(x='ERA', y='Team', data=df2_sorted, palette=['red' if era > df2_sorted['ERA'].mean() else 'blue' for era in df2_sorted['ERA']])

# 평균값 계산
mean_value = df2_sorted['ERA'].mean()

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (era, team) in enumerate(zip(df2_sorted['ERA'], df2_sorted['Team'])):
    color = 'red' if era > mean_value else 'blue'
    ax.text(era, idx, f'{era:.2f}', color=color, ha="left", va="center")

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean ERA')

# 그래프 제목 추가
plt.title('팀별 평균자책점(ERA)')

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10940\198808358.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='ERA', y='Team', data=df2_sorted, palette=['red' if era > df2_sorted['ERA'].mean() else 'blue' for era in df2_sorted['ERA']])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 'ERA' 열을 기준으로 데이터프레임을 내림차순으로 정렬
df2_sorted = df2.sort_values(by='ERA', ascending=False)

# 판다스 DataFrame에서 '팀'과 'ERA' 열을 사용하여 시각화
ax = sns.barplot(x='ERA', y='Team', data=df2_sorted, palette=['red' if era > df2_sorted['ERA'].mean() else 'blue' for era in df2_sorted['ERA']])

# 평균값 계산
mean_value = df2_sorted['ERA'].mean()

# 평균값을 넘은 데이터를 다르게 색칠하고 표시
for idx, (era, team) in enumerate(zip(df2_sorted['ERA'], df2_sorted['Team'])):
    color = 'red' if era > mean_value else 'blue'
    ax.text(era, idx, f'{era:.2f}', color=color, ha="left", va="center")

# 평균값 선 추가
ax.axvline(x=mean_value, color='black', linestyle='--', label='Mean ERA')

# 그래프 제목 추가
plt.title('팀별 평균자책점(ERA)')

# y축 라벨 회전
plt.yticks(rotation=0)

# 그래프 출력
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10940\3565643116.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='ERA', y='Team', data=df2_sorted, palette=['red' if era > df2_sorted['ERA'].mean() else 'blue' for era in df2_sorted['ERA']])
